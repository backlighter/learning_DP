# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision.datasets import MNIST
from torchvision.transforms import ToTensor
from torch.utils.data import DataLoader
import time

# 设置平台  GPU/ CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
num_workers=16
start_time = time.time()
# 定义前馈神经网络模型
class FeedforwardNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(FeedforwardNN, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        
        self.fc2 = nn.Linear(hidden_size, 128)
        self.relu2 = nn.ReLU()
        
        self.fc3 = nn.Linear(128, num_classes)
        
    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        out = self.relu2(out)
        out = self.fc3(out)
        return out

# 定义超参数
input_size = 28 * 28  # 输入特征的维度
hidden_size = 512  # 隐藏层的大小
num_classes = 10  # 类别的数量
learning_rate = 0.001  # 学习率
num_epochs = 20  # 迭代次数
batch_size = 64  # 批次大小

# 加载数据集
train_dataset = MNIST(root='~/Datasets/MNIST', train=True, transform=ToTensor(), download=True)
test_dataset = MNIST(root='~/Datasets/MNIST', train=False, transform=ToTensor(), download=False)

train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# 初始化模型
model = FeedforwardNN(input_size, hidden_size, num_classes).to(device)

# 定义损失函数和优化器
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# 训练模型
for epoch in range(num_epochs):
    model.train()
    for batch_idx, (data, targets) in enumerate(train_loader):
        data = data.view(-1, input_size).to(device)
        targets=targets.to(device)
        # 前向传播
        outputs = model(data)
        loss = criterion(outputs, targets)
        
        # 反向传播和优化
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if (batch_idx+1) % 100 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{batch_idx+1}/{len(train_loader)}], Loss: {loss.item():.4f}')


    # 在测试集上评估模型
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for data, targets in test_loader:
            data = data.view(-1, input_size).to(device)
            targets=targets.to(device)
            outputs = model(data)
            _, predicted = torch.max(outputs.data, 1)
            total += targets.size(0)
            correct += (predicted == targets).sum().item()
        
        accuracy = correct / total
        print(f'Test Accuracy: {accuracy:.4f}')
            
end_time = time.time()
training_time = end_time - start_time
print("模型的training_time为"+str(round(training_time,2))+"秒" )
# Out:
# cuda
# Epoch [1/20], Step [100/938], Loss: 0.2905
# Epoch [1/20], Step [200/938], Loss: 0.2730
# Epoch [1/20], Step [300/938], Loss: 0.2407
# Epoch [1/20], Step [400/938], Loss: 0.3394
# Epoch [1/20], Step [500/938], Loss: 0.1672
# Epoch [1/20], Step [600/938], Loss: 0.0833
# Epoch [1/20], Step [700/938], Loss: 0.2129
# Epoch [1/20], Step [800/938], Loss: 0.1017
# Epoch [1/20], Step [900/938], Loss: 0.0860
# Test Accuracy: 0.9575
# Epoch [2/20], Step [100/938], Loss: 0.2148
# Epoch [2/20], Step [200/938], Loss: 0.0341
# Epoch [2/20], Step [300/938], Loss: 0.0666
# Epoch [2/20], Step [400/938], Loss: 0.0275
# Epoch [2/20], Step [500/938], Loss: 0.0720
# Epoch [2/20], Step [600/938], Loss: 0.1652
# Epoch [2/20], Step [700/938], Loss: 0.1212
# Epoch [2/20], Step [800/938], Loss: 0.2096
# Epoch [2/20], Step [900/938], Loss: 0.0755
# Test Accuracy: 0.9747
# Epoch [3/20], Step [100/938], Loss: 0.0411
# Epoch [3/20], Step [200/938], Loss: 0.0676
# Epoch [3/20], Step [300/938], Loss: 0.0201
# Epoch [3/20], Step [400/938], Loss: 0.0330
# Epoch [3/20], Step [500/938], Loss: 0.0147
# Epoch [3/20], Step [600/938], Loss: 0.1081
# Epoch [3/20], Step [700/938], Loss: 0.0783
# Epoch [3/20], Step [800/938], Loss: 0.0363
# Epoch [3/20], Step [900/938], Loss: 0.0539
# Test Accuracy: 0.9754
# Epoch [4/20], Step [100/938], Loss: 0.0177
# Epoch [4/20], Step [200/938], Loss: 0.0694
# Epoch [4/20], Step [300/938], Loss: 0.0044
# Epoch [4/20], Step [400/938], Loss: 0.0069
# Epoch [4/20], Step [500/938], Loss: 0.0657
# Epoch [4/20], Step [600/938], Loss: 0.0333
# Epoch [4/20], Step [700/938], Loss: 0.0571
# Epoch [4/20], Step [800/938], Loss: 0.0104
# Epoch [4/20], Step [900/938], Loss: 0.2117
# Test Accuracy: 0.9775
# Epoch [5/20], Step [100/938], Loss: 0.0179
# Epoch [5/20], Step [200/938], Loss: 0.0162
# Epoch [5/20], Step [300/938], Loss: 0.0233
# Epoch [5/20], Step [400/938], Loss: 0.0094
# Epoch [5/20], Step [500/938], Loss: 0.0280
# Epoch [5/20], Step [600/938], Loss: 0.0639
# Epoch [5/20], Step [700/938], Loss: 0.0795
# Epoch [5/20], Step [800/938], Loss: 0.0287
# Epoch [18/20], Step [700/938], Loss: 0.0003
# Epoch [18/20], Step [800/938], Loss: 0.0000
# Epoch [18/20], Step [900/938], Loss: 0.0000
# Test Accuracy: 0.9830
# Epoch [19/20], Step [100/938], Loss: 0.0001
# Epoch [19/20], Step [200/938], Loss: 0.0317
# Epoch [19/20], Step [300/938], Loss: 0.0020
# Epoch [19/20], Step [400/938], Loss: 0.0050
# Epoch [19/20], Step [500/938], Loss: 0.0011
# Epoch [19/20], Step [600/938], Loss: 0.0000
# Epoch [19/20], Step [700/938], Loss: 0.0000
# Epoch [19/20], Step [800/938], Loss: 0.0008
# Epoch [19/20], Step [900/938], Loss: 0.0749
# Test Accuracy: 0.9832
# Epoch [20/20], Step [100/938], Loss: 0.0000
# Epoch [20/20], Step [200/938], Loss: 0.0003
# Epoch [20/20], Step [300/938], Loss: 0.0000
# Epoch [20/20], Step [400/938], Loss: 0.0000
# Epoch [20/20], Step [500/938], Loss: 0.0000
# Epoch [20/20], Step [600/938], Loss: 0.0017
# Epoch [20/20], Step [700/938], Loss: 0.0242
# Epoch [20/20], Step [800/938], Loss: 0.0012
# Epoch [20/20], Step [900/938], Loss: 0.0023
# Test Accuracy: 0.9801
# 模型的training_time为904.15秒

# %%
# 保存模型
torch.save(model.state_dict(), 'multi_class_model.pth')

# %%
# 加载模型
model = FeedforwardNN(input_size, hidden_size, num_classes)
model.load_state_dict(torch.load('multi_class_model.pth'))
# Out:
# <All keys matched successfully>

# %%
# 定义损失函数和优化器
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# 训练模型
for epoch in range(num_epochs):
    model.train()
    for batch_idx, (data, targets) in enumerate(train_loader):
        data = data.view(-1, input_size)
        
        # 前向传播
        outputs = model(data)
        loss = criterion(outputs, targets)
        
        # 反向传播和优化
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if (batch_idx+1) % 100 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{batch_idx+1}/{len(train_loader)}], Loss: {loss.item():.4f}')
    
    # 在测试集上评估模型
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for data, targets in test_loader:
            data = data.view(-1, input_size)
            outputs = model(data)
            _, predicted = torch.max(outputs.data, 1)
            total += targets.size(0)
            correct += (predicted == targets).sum().item()
        
        accuracy = correct / total
        print(f'Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch [1/10], Step [100/938], Loss: 0.0170
# Epoch [1/10], Step [200/938], Loss: 0.0123
# Epoch [1/10], Step [300/938], Loss: 0.0050
# Epoch [1/10], Step [400/938], Loss: 0.0298
# Epoch [1/10], Step [500/938], Loss: 0.0229
# Epoch [1/10], Step [600/938], Loss: 0.0043
# Epoch [1/10], Step [700/938], Loss: 0.0297
# Epoch [1/10], Step [800/938], Loss: 0.0106
# Epoch [1/10], Step [900/938], Loss: 0.0120
# Test Accuracy: 0.9772
# Epoch [2/10], Step [100/938], Loss: 0.0030
# Epoch [2/10], Step [200/938], Loss: 0.0466
# Epoch [2/10], Step [300/938], Loss: 0.0191
# Epoch [2/10], Step [400/938], Loss: 0.0022
# Epoch [2/10], Step [500/938], Loss: 0.0074
# Epoch [2/10], Step [600/938], Loss: 0.0042
# Epoch [2/10], Step [700/938], Loss: 0.0077
# Epoch [2/10], Step [800/938], Loss: 0.0084
# Epoch [2/10], Step [900/938], Loss: 0.0368
# Test Accuracy: 0.9757
# Epoch [3/10], Step [100/938], Loss: 0.0143
# Epoch [3/10], Step [200/938], Loss: 0.0227
# Epoch [3/10], Step [300/938], Loss: 0.0034
# Epoch [3/10], Step [400/938], Loss: 0.0032
# Epoch [3/10], Step [500/938], Loss: 0.0018
# Epoch [3/10], Step [600/938], Loss: 0.0204
# Epoch [3/10], Step [700/938], Loss: 0.0138
# Epoch [3/10], Step [800/938], Loss: 0.0201
# Epoch [3/10], Step [900/938], Loss: 0.0120
# Test Accuracy: 0.9758
# Epoch [4/10], Step [100/938], Loss: 0.0158
# Epoch [4/10], Step [200/938], Loss: 0.0012
# Epoch [4/10], Step [300/938], Loss: 0.0263
# Epoch [4/10], Step [400/938], Loss: 0.0014
# Epoch [4/10], Step [500/938], Loss: 0.0050
# Epoch [4/10], Step [600/938], Loss: 0.0012
# Epoch [4/10], Step [700/938], Loss: 0.0332
# Epoch [4/10], Step [800/938], Loss: 0.0088
# Epoch [4/10], Step [900/938], Loss: 0.0377
# Test Accuracy: 0.9766
# Epoch [5/10], Step [100/938], Loss: 0.0011
# Epoch [5/10], Step [200/938], Loss: 0.0026
# Epoch [5/10], Step [300/938], Loss: 0.0020
# Epoch [5/10], Step [400/938], Loss: 0.0086
# Epoch [5/10], Step [500/938], Loss: 0.0014
# Epoch [5/10], Step [600/938], Loss: 0.0059
# Epoch [5/10], Step [700/938], Loss: 0.0016
# Epoch [5/10], Step [800/938], Loss: 0.0016
# Epoch [5/10], Step [900/938], Loss: 0.0135
# Test Accuracy: 0.9791
# Epoch [6/10], Step [100/938], Loss: 0.0017
# Epoch [6/10], Step [200/938], Loss: 0.0060
# Epoch [6/10], Step [300/938], Loss: 0.0042
# Epoch [6/10], Step [400/938], Loss: 0.0076
# Epoch [6/10], Step [500/938], Loss: 0.0076
# Epoch [6/10], Step [600/938], Loss: 0.0022
# Epoch [6/10], Step [700/938], Loss: 0.0030
# Epoch [6/10], Step [800/938], Loss: 0.0069
# Epoch [6/10], Step [900/938], Loss: 0.0117
# Test Accuracy: 0.9793
# Epoch [7/10], Step [100/938], Loss: 0.0262
# Epoch [7/10], Step [200/938], Loss: 0.0090
# Epoch [7/10], Step [300/938], Loss: 0.0026
# Epoch [7/10], Step [400/938], Loss: 0.0003
# Epoch [7/10], Step [500/938], Loss: 0.0021
# Epoch [7/10], Step [600/938], Loss: 0.0096
# Epoch [7/10], Step [700/938], Loss: 0.0007
# Epoch [7/10], Step [800/938], Loss: 0.0054
# Epoch [7/10], Step [900/938], Loss: 0.0045
# Test Accuracy: 0.9788
# Epoch [8/10], Step [100/938], Loss: 0.0111
# Epoch [8/10], Step [200/938], Loss: 0.0027
# Epoch [8/10], Step [300/938], Loss: 0.0035
# Epoch [8/10], Step [400/938], Loss: 0.0004
# Epoch [8/10], Step [500/938], Loss: 0.0018
# Epoch [8/10], Step [600/938], Loss: 0.0028
# Epoch [8/10], Step [700/938], Loss: 0.0015
# Epoch [8/10], Step [800/938], Loss: 0.0022
# Epoch [8/10], Step [900/938], Loss: 0.0100
# Test Accuracy: 0.9766
# Epoch [9/10], Step [100/938], Loss: 0.0022
# Epoch [9/10], Step [200/938], Loss: 0.0039
# Epoch [9/10], Step [300/938], Loss: 0.0038
# Epoch [9/10], Step [400/938], Loss: 0.0012
# Epoch [9/10], Step [500/938], Loss: 0.0039
# Epoch [9/10], Step [600/938], Loss: 0.0043
# Epoch [9/10], Step [700/938], Loss: 0.0024
# Epoch [9/10], Step [800/938], Loss: 0.0034
# Epoch [9/10], Step [900/938], Loss: 0.0004
# Test Accuracy: 0.9783
# Epoch [10/10], Step [100/938], Loss: 0.0011
# Epoch [10/10], Step [200/938], Loss: 0.0008
# Epoch [10/10], Step [300/938], Loss: 0.0023
# Epoch [10/10], Step [400/938], Loss: 0.0015
# Epoch [10/10], Step [500/938], Loss: 0.0002
# Epoch [10/10], Step [600/938], Loss: 0.0008
# Epoch [10/10], Step [700/938], Loss: 0.0008
# Epoch [10/10], Step [800/938], Loss: 0.0006
# Epoch [10/10], Step [900/938], Loss: 0.0043
# Test Accuracy: 0.9752
