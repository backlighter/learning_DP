# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision.datasets import MNIST
from torchvision.transforms import ToTensor
from torch.utils.data import DataLoader


# 设置平台  GPU/ CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
num_workers=16
# 定义前馈神经网络模型
class FeedforwardNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(FeedforwardNN, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, num_classes)
        
    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        return out

# 定义超参数
input_size = 28 * 28  # 输入特征的维度
hidden_size = 128  # 隐藏层的大小
num_classes = 10  # 类别的数量
learning_rate = 0.001  # 学习率
num_epochs = 10  # 迭代次数
batch_size = 64  # 批次大小

# 加载数据集
train_dataset = MNIST(root='~/Datasets/MNIST', train=True, transform=ToTensor(), download=True)
test_dataset = MNIST(root='~/Datasets/MNIST', train=False, transform=ToTensor(), download=False)

train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# 初始化模型
model = FeedforwardNN(input_size, hidden_size, num_classes).to(device)

# 定义损失函数和优化器
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate)

# 训练模型
for epoch in range(num_epochs):
    model.train()
    for batch_idx, (data, targets) in enumerate(train_loader):
        data = data.view(-1, input_size).to(device)
        targets=targets.to(device)
        # 前向传播
        outputs = model(data)
        loss = criterion(outputs, targets)
        
        # 反向传播和优化
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if (batch_idx+1) % 100 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{batch_idx+1}/{len(train_loader)}], Loss: {loss.item():.4f}')
    
    # 在测试集上评估模型
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for data, targets in test_loader:
            data = data.view(-1, input_size).to(device)
            targets=targets.to(device)
            outputs = model(data)
            _, predicted = torch.max(outputs.data, 1)
            total += targets.size(0)
            correct += (predicted == targets).sum().item()
        
        accuracy = correct / total
        print(f'Test Accuracy: {accuracy:.4f}')
# Out:
# cuda
# Epoch [1/10], Step [100/938], Loss: 2.2763
# Epoch [1/10], Step [200/938], Loss: 2.2946
# Epoch [1/10], Step [300/938], Loss: 2.2628
# Epoch [1/10], Step [400/938], Loss: 2.2396
# Epoch [1/10], Step [500/938], Loss: 2.2268
# Epoch [1/10], Step [600/938], Loss: 2.2061
# Epoch [1/10], Step [700/938], Loss: 2.1768
# Epoch [1/10], Step [800/938], Loss: 2.1541
# Epoch [1/10], Step [900/938], Loss: 2.1266
# Test Accuracy: 0.5502
# Epoch [2/10], Step [100/938], Loss: 2.0903
# Epoch [2/10], Step [200/938], Loss: 2.0265
# Epoch [2/10], Step [300/938], Loss: 2.0407
# Epoch [2/10], Step [400/938], Loss: 2.0483
# Epoch [2/10], Step [500/938], Loss: 1.9800
# Epoch [2/10], Step [600/938], Loss: 1.9661
# Epoch [2/10], Step [700/938], Loss: 1.9707
# Epoch [2/10], Step [800/938], Loss: 1.8926
# Epoch [2/10], Step [900/938], Loss: 1.8859
# Test Accuracy: 0.7064
# Epoch [3/10], Step [100/938], Loss: 1.8428
# Epoch [3/10], Step [200/938], Loss: 1.7829
# Epoch [3/10], Step [300/938], Loss: 1.7514
# Epoch [3/10], Step [400/938], Loss: 1.7457
# Epoch [3/10], Step [500/938], Loss: 1.7427
# Epoch [3/10], Step [600/938], Loss: 1.7164
# Epoch [3/10], Step [700/938], Loss: 1.5597
# Epoch [3/10], Step [800/938], Loss: 1.6077
# Epoch [3/10], Step [900/938], Loss: 1.4610
# Test Accuracy: 0.7563
# Epoch [4/10], Step [100/938], Loss: 1.4937
# Epoch [4/10], Step [200/938], Loss: 1.4287
# Epoch [4/10], Step [300/938], Loss: 1.5215
# Epoch [4/10], Step [400/938], Loss: 1.3789
# Epoch [4/10], Step [500/938], Loss: 1.5111
# Epoch [4/10], Step [600/938], Loss: 1.3583
# Epoch [4/10], Step [700/938], Loss: 1.3728
# Epoch [4/10], Step [800/938], Loss: 1.3288
# Epoch [4/10], Step [900/938], Loss: 1.2441
# Test Accuracy: 0.7848
# Epoch [5/10], Step [100/938], Loss: 1.3672
# Epoch [5/10], Step [200/938], Loss: 1.2424
# Epoch [10/10], Step [700/938], Loss: 0.6164
# Epoch [10/10], Step [800/938], Loss: 0.8898
# Epoch [10/10], Step [900/938], Loss: 0.7324
# Test Accuracy: 0.8615

# %%
# 保存模型
torch.save(model.state_dict(), 'multi_class_model2.pth')

# %%
# 加载模型
model = FeedforwardNN(input_size, hidden_size, num_classes)
model.load_state_dict(torch.load('multi_class_model2.pth'))
# 定义损失函数和优化器
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate)

# 训练模型
for epoch in range(num_epochs):
    model.train()
    for batch_idx, (data, targets) in enumerate(train_loader):
        data = data.view(-1, input_size)
        
        # 前向传播
        outputs = model(data)
        loss = criterion(outputs, targets)
        
        # 反向传播和优化
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if (batch_idx+1) % 100 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{batch_idx+1}/{len(train_loader)}], Loss: {loss.item():.4f}')
    
    # 在测试集上评估模型
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for data, targets in test_loader:
            data = data.view(-1, input_size)
            outputs = model(data)
            _, predicted = torch.max(outputs.data, 1)
            total += targets.size(0)
            correct += (predicted == targets).sum().item()
        
        accuracy = correct / total
        print(f'Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch [1/10], Step [100/938], Loss: 0.5676
# Epoch [1/10], Step [200/938], Loss: 0.5472
# Epoch [1/10], Step [300/938], Loss: 0.6570
# Epoch [1/10], Step [400/938], Loss: 0.5125
# Epoch [1/10], Step [500/938], Loss: 0.5669
# Epoch [1/10], Step [600/938], Loss: 0.5487
# Epoch [1/10], Step [700/938], Loss: 0.5582
# Epoch [1/10], Step [800/938], Loss: 0.4306
# Epoch [1/10], Step [900/938], Loss: 0.6254
# Test Accuracy: 0.8658
# Epoch [2/10], Step [100/938], Loss: 0.5308
# Epoch [2/10], Step [200/938], Loss: 0.6531
# Epoch [2/10], Step [300/938], Loss: 0.5028
# Epoch [2/10], Step [400/938], Loss: 0.4597
# Epoch [2/10], Step [500/938], Loss: 0.4710
# Epoch [2/10], Step [600/938], Loss: 0.5873
# Epoch [2/10], Step [700/938], Loss: 0.4174
# Epoch [2/10], Step [800/938], Loss: 0.5174
# Epoch [2/10], Step [900/938], Loss: 0.5666
# Test Accuracy: 0.8710
# Epoch [3/10], Step [100/938], Loss: 0.4539
# Epoch [3/10], Step [200/938], Loss: 0.6778
# Epoch [3/10], Step [300/938], Loss: 0.5795
# Epoch [3/10], Step [400/938], Loss: 0.4309
# Epoch [3/10], Step [500/938], Loss: 0.3629
# Epoch [3/10], Step [600/938], Loss: 0.4683
# Epoch [3/10], Step [700/938], Loss: 0.5802
# Epoch [3/10], Step [800/938], Loss: 0.5321
# Epoch [3/10], Step [900/938], Loss: 0.5717
# Test Accuracy: 0.8756
# Epoch [4/10], Step [100/938], Loss: 0.5399
# Epoch [4/10], Step [200/938], Loss: 0.4506
# Epoch [4/10], Step [300/938], Loss: 0.4394
# Epoch [4/10], Step [400/938], Loss: 0.5208
# Epoch [4/10], Step [500/938], Loss: 0.5189
# Epoch [4/10], Step [600/938], Loss: 0.5795
# Epoch [4/10], Step [700/938], Loss: 0.4766
# Epoch [4/10], Step [800/938], Loss: 0.5541
# Epoch [4/10], Step [900/938], Loss: 0.4027
# Test Accuracy: 0.8792
# Epoch [5/10], Step [100/938], Loss: 0.4521
# Epoch [5/10], Step [200/938], Loss: 0.5050
# Epoch [5/10], Step [300/938], Loss: 0.6286
# Epoch [5/10], Step [400/938], Loss: 0.5207
# Epoch [5/10], Step [500/938], Loss: 0.3733
# Epoch [5/10], Step [600/938], Loss: 0.3416
# Epoch [5/10], Step [700/938], Loss: 0.4606
# Epoch [5/10], Step [800/938], Loss: 0.5499
# Epoch [5/10], Step [900/938], Loss: 0.4420
# Test Accuracy: 0.8830
# Epoch [6/10], Step [100/938], Loss: 0.5076
# Epoch [6/10], Step [200/938], Loss: 0.6109
# Epoch [6/10], Step [300/938], Loss: 0.4589
# Epoch [6/10], Step [400/938], Loss: 0.7128
# Epoch [6/10], Step [500/938], Loss: 0.4740
# Epoch [6/10], Step [600/938], Loss: 0.4018
# Epoch [6/10], Step [700/938], Loss: 0.3896
# Epoch [6/10], Step [800/938], Loss: 0.4498
# Epoch [6/10], Step [900/938], Loss: 0.5442
# Test Accuracy: 0.8852
# Epoch [7/10], Step [100/938], Loss: 0.5067
# Epoch [7/10], Step [200/938], Loss: 0.4747
# Epoch [7/10], Step [300/938], Loss: 0.4660
# Epoch [7/10], Step [400/938], Loss: 0.5561
# Epoch [7/10], Step [500/938], Loss: 0.4061
# Epoch [7/10], Step [600/938], Loss: 0.7619
# Epoch [7/10], Step [700/938], Loss: 0.5381
# Epoch [7/10], Step [800/938], Loss: 0.3956
# Epoch [7/10], Step [900/938], Loss: 0.3978
# Test Accuracy: 0.8880
# Epoch [8/10], Step [100/938], Loss: 0.3884
# Epoch [8/10], Step [200/938], Loss: 0.4780
# Epoch [8/10], Step [300/938], Loss: 0.4969
# Epoch [8/10], Step [400/938], Loss: 0.3985
# Epoch [8/10], Step [500/938], Loss: 0.4417
# Epoch [8/10], Step [600/938], Loss: 0.6963
# Epoch [8/10], Step [700/938], Loss: 0.5337
# Epoch [8/10], Step [800/938], Loss: 0.3677
# Epoch [8/10], Step [900/938], Loss: 0.5799
# Test Accuracy: 0.8897
# Epoch [9/10], Step [100/938], Loss: 0.4228
# Epoch [9/10], Step [200/938], Loss: 0.5733
# Epoch [9/10], Step [300/938], Loss: 0.4348
# Epoch [9/10], Step [400/938], Loss: 0.6131
# Epoch [9/10], Step [500/938], Loss: 0.4099
# Epoch [9/10], Step [600/938], Loss: 0.4784
# Epoch [9/10], Step [700/938], Loss: 0.3958
# Epoch [9/10], Step [800/938], Loss: 0.3928
# Epoch [9/10], Step [900/938], Loss: 0.4699
# Test Accuracy: 0.8912
# Epoch [10/10], Step [100/938], Loss: 0.4426
# Epoch [10/10], Step [200/938], Loss: 0.5405
# Epoch [10/10], Step [300/938], Loss: 0.4237
# Epoch [10/10], Step [400/938], Loss: 0.3554
# Epoch [10/10], Step [500/938], Loss: 0.3435
# Epoch [10/10], Step [600/938], Loss: 0.4237
# Epoch [10/10], Step [700/938], Loss: 0.5747
# Epoch [10/10], Step [800/938], Loss: 0.3864
# Epoch [10/10], Step [900/938], Loss: 0.4979
# Test Accuracy: 0.8929
