# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision.datasets import MNIST
from torchvision.transforms import ToTensor
from torch.utils.data import DataLoader
import time

# 设置平台  GPU/ CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
num_workers=16

# 定义Swish激活函数
class Swish(nn.Module):
    def __init__(self, beta=1.0):
        super(Swish, self).__init__()
        self.beta = beta

    def forward(self, x):
        return x * torch.sigmoid(self.beta * x)
start_time = time.time()
# 定义前馈神经网络模型
class FeedforwardNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(FeedforwardNN, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        #self.relu = nn.LeakyReLU(negative_slope=0.01)
        self.swish = Swish()  # 使用Swish激活函数
        self.fc2 = nn.Linear(hidden_size, 128)
        #self.relu2 = nn.LeakyReLU(negative_slope=0.01)
        self.swish2 = Swish()  # 使用Swish激活函数
        self.fc3 = nn.Linear(128, num_classes)
        
    def forward(self, x):
        out = self.fc1(x)
        out = self.swish(out)
        out = self.fc2(out)
        out = self.swish2(out)
        out = self.fc3(out)
        return out

# 定义超参数
input_size = 28 * 28  # 输入特征的维度
hidden_size = 512  # 隐藏层的大小
num_classes = 10  # 类别的数量
learning_rate = 0.001  # 学习率
num_epochs = 20  # 迭代次数
batch_size = 64  # 批次大小

# 加载数据集
train_dataset = MNIST(root='~/Datasets/MNIST', train=True, transform=ToTensor(), download=True)
test_dataset = MNIST(root='~/Datasets/MNIST', train=False, transform=ToTensor(), download=False)

train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True,num_workers=num_workers)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False,num_workers=num_workers)

# 初始化模型
model = FeedforwardNN(input_size, hidden_size, num_classes).to(device)

# 定义损失函数和优化器
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)


#画图
losses = []
accuracy = []
# 训练模型
for epoch in range(num_epochs):
    model.train()
    for batch_idx, (data, targets) in enumerate(train_loader):
        data = data.view(-1, input_size).to(device)
        targets = targets.to(device)
        # 前向传播
        outputs = model(data)
        loss = criterion(outputs, targets)
        
        # 反向传播和优化
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if (batch_idx+1) % 100 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{batch_idx+1}/{len(train_loader)}], Loss: {loss.item():.4f}')
    _, predicted = torch.max(outputs.data, 1)
    acc = (predicted == targets).sum().item() / targets.size(0)
    accuracy.append(acc)
    # 记录损失和准确率
    losses.append(loss.item())
    print(f'Train Accuracy: {acc:.4f}')
    
    
    # 在测试集上评估模型
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for data, targets in test_loader:
            data = data.view(-1, input_size).to(device)
            targets = targets.to(device)
            outputs = model(data)
            _, predicted = torch.max(outputs.data, 1)
            total += targets.size(0)
            correct += (predicted == targets).sum().item()
        
        
        acc = correct / total
        print(f'Test Accuracy: {acc:.4f}')
        
            
end_time = time.time()
training_time = end_time - start_time
print("模型的training_time为"+str(round(training_time,2))+"秒" )
# Out:
# cuda
# Epoch [1/20], Step [100/938], Loss: 0.4267
# Epoch [1/20], Step [200/938], Loss: 0.3412
# Epoch [1/20], Step [300/938], Loss: 0.2344
# Epoch [1/20], Step [400/938], Loss: 0.1422
# Epoch [1/20], Step [500/938], Loss: 0.2020
# Epoch [1/20], Step [600/938], Loss: 0.2245
# Epoch [1/20], Step [700/938], Loss: 0.2452
# Epoch [1/20], Step [800/938], Loss: 0.2067
# Epoch [1/20], Step [900/938], Loss: 0.1096
# Train Accuracy: 0.9375
# Test Accuracy: 0.9629
# Epoch [2/20], Step [100/938], Loss: 0.1243
# Epoch [2/20], Step [200/938], Loss: 0.1050
# Epoch [2/20], Step [300/938], Loss: 0.1760
# Epoch [2/20], Step [400/938], Loss: 0.0342
# Epoch [2/20], Step [500/938], Loss: 0.1597
# Epoch [2/20], Step [600/938], Loss: 0.0444
# Epoch [2/20], Step [700/938], Loss: 0.1713
# Epoch [2/20], Step [800/938], Loss: 0.0179
# Epoch [2/20], Step [900/938], Loss: 0.1553
# Train Accuracy: 0.9688
# Test Accuracy: 0.9724
# Epoch [3/20], Step [100/938], Loss: 0.0266
# Epoch [3/20], Step [200/938], Loss: 0.1908
# Epoch [3/20], Step [300/938], Loss: 0.0580
# Epoch [3/20], Step [400/938], Loss: 0.0174
# Epoch [3/20], Step [500/938], Loss: 0.1217
# Epoch [3/20], Step [600/938], Loss: 0.1028
# Epoch [3/20], Step [700/938], Loss: 0.0478
# Epoch [3/20], Step [800/938], Loss: 0.0363
# Epoch [3/20], Step [900/938], Loss: 0.0261
# Train Accuracy: 1.0000
# Test Accuracy: 0.9743
# Epoch [4/20], Step [100/938], Loss: 0.0183
# Epoch [4/20], Step [200/938], Loss: 0.0036
# Epoch [4/20], Step [300/938], Loss: 0.1172
# Epoch [4/20], Step [400/938], Loss: 0.0026
# Epoch [4/20], Step [500/938], Loss: 0.0099
# Epoch [4/20], Step [600/938], Loss: 0.0702
# Epoch [4/20], Step [700/938], Loss: 0.0118
# Epoch [4/20], Step [800/938], Loss: 0.1677
# Epoch [4/20], Step [900/938], Loss: 0.0113
# Train Accuracy: 1.0000
# Test Accuracy: 0.9777
# Epoch [5/20], Step [100/938], Loss: 0.0655
# Epoch [5/20], Step [200/938], Loss: 0.0188
# Epoch [5/20], Step [300/938], Loss: 0.0440
# Epoch [5/20], Step [400/938], Loss: 0.0340
# Epoch [5/20], Step [500/938], Loss: 0.0097
# Epoch [5/20], Step [600/938], Loss: 0.0215
# Epoch [5/20], Step [700/938], Loss: 0.0227
# Epoch [5/20], Step [800/938], Loss: 0.0280
# Epoch [5/20], Step [900/938], Loss: 0.0079
# Train Accuracy: 1.0000
# Test Accuracy: 0.9803
# Epoch [6/20], Step [100/938], Loss: 0.0024
# Epoch [6/20], Step [200/938], Loss: 0.0103
# Epoch [6/20], Step [300/938], Loss: 0.0064
# Epoch [6/20], Step [400/938], Loss: 0.0279
# Epoch [6/20], Step [500/938], Loss: 0.0128
# Epoch [6/20], Step [600/938], Loss: 0.0783
# Epoch [6/20], Step [700/938], Loss: 0.0165
# Epoch [6/20], Step [800/938], Loss: 0.0036
# Epoch [6/20], Step [900/938], Loss: 0.1217
# Train Accuracy: 1.0000
# Test Accuracy: 0.9796
# Epoch [7/20], Step [100/938], Loss: 0.0098
# Epoch [7/20], Step [200/938], Loss: 0.0013
# Epoch [7/20], Step [300/938], Loss: 0.0030
# Epoch [7/20], Step [400/938], Loss: 0.0027
# Epoch [7/20], Step [500/938], Loss: 0.1010
# Epoch [7/20], Step [600/938], Loss: 0.0004
# Epoch [7/20], Step [700/938], Loss: 0.0020
# Epoch [7/20], Step [800/938], Loss: 0.0013
# Epoch [7/20], Step [900/938], Loss: 0.0017
# Train Accuracy: 1.0000
# Test Accuracy: 0.9806
# Epoch [8/20], Step [100/938], Loss: 0.0014
# Epoch [8/20], Step [200/938], Loss: 0.0686
# Epoch [8/20], Step [300/938], Loss: 0.0160
# Epoch [8/20], Step [400/938], Loss: 0.0042
# Epoch [8/20], Step [500/938], Loss: 0.0450
# Epoch [8/20], Step [600/938], Loss: 0.0774
# Epoch [8/20], Step [700/938], Loss: 0.0019
# Epoch [8/20], Step [800/938], Loss: 0.0553
# Epoch [8/20], Step [900/938], Loss: 0.0063
# Train Accuracy: 1.0000
# Test Accuracy: 0.9803
# Epoch [9/20], Step [100/938], Loss: 0.0081
# Epoch [9/20], Step [200/938], Loss: 0.0069
# Epoch [9/20], Step [300/938], Loss: 0.0005
# Epoch [9/20], Step [400/938], Loss: 0.0005
# Epoch [9/20], Step [500/938], Loss: 0.0184
# Epoch [9/20], Step [600/938], Loss: 0.0165
# Epoch [9/20], Step [700/938], Loss: 0.0831
# Epoch [9/20], Step [800/938], Loss: 0.0005
# Epoch [9/20], Step [900/938], Loss: 0.0021
# Train Accuracy: 1.0000
# Test Accuracy: 0.9801
# Epoch [10/20], Step [100/938], Loss: 0.0065
# Epoch [10/20], Step [200/938], Loss: 0.0119
# Epoch [10/20], Step [300/938], Loss: 0.0064
# Epoch [10/20], Step [400/938], Loss: 0.0034
# Epoch [10/20], Step [500/938], Loss: 0.0021
# Epoch [10/20], Step [600/938], Loss: 0.0027
# Epoch [10/20], Step [700/938], Loss: 0.0598
# Epoch [10/20], Step [800/938], Loss: 0.0936
# Epoch [10/20], Step [900/938], Loss: 0.0050
# Train Accuracy: 1.0000
# Test Accuracy: 0.9794
# Epoch [11/20], Step [100/938], Loss: 0.0138
# Epoch [11/20], Step [200/938], Loss: 0.0005
# Epoch [11/20], Step [300/938], Loss: 0.0055
# Epoch [11/20], Step [400/938], Loss: 0.0001
# Epoch [11/20], Step [500/938], Loss: 0.0001
# Epoch [11/20], Step [600/938], Loss: 0.0013
# Epoch [11/20], Step [700/938], Loss: 0.0027
# Epoch [11/20], Step [800/938], Loss: 0.0289
# Epoch [11/20], Step [900/938], Loss: 0.0071
# Train Accuracy: 1.0000
# Test Accuracy: 0.9828
# Epoch [12/20], Step [100/938], Loss: 0.0006
# Epoch [12/20], Step [200/938], Loss: 0.0485
# Epoch [12/20], Step [300/938], Loss: 0.0371
# Epoch [12/20], Step [400/938], Loss: 0.0092
# Epoch [12/20], Step [500/938], Loss: 0.0007
# Epoch [12/20], Step [600/938], Loss: 0.0001
# Epoch [12/20], Step [700/938], Loss: 0.0006
# Epoch [12/20], Step [800/938], Loss: 0.0015
# Epoch [12/20], Step [900/938], Loss: 0.0304
# Train Accuracy: 1.0000
# Test Accuracy: 0.9787
# Epoch [13/20], Step [100/938], Loss: 0.0206
# Epoch [13/20], Step [200/938], Loss: 0.0007
# Epoch [13/20], Step [300/938], Loss: 0.0004
# Epoch [13/20], Step [400/938], Loss: 0.0010
# Epoch [13/20], Step [500/938], Loss: 0.0208
# Epoch [13/20], Step [600/938], Loss: 0.0339
# Epoch [13/20], Step [700/938], Loss: 0.0079
# Epoch [13/20], Step [800/938], Loss: 0.0010
# Epoch [13/20], Step [900/938], Loss: 0.0837
# Train Accuracy: 1.0000
# Test Accuracy: 0.9789
# Epoch [14/20], Step [100/938], Loss: 0.0019
# Epoch [14/20], Step [200/938], Loss: 0.0021
# Epoch [14/20], Step [300/938], Loss: 0.0162
# Epoch [14/20], Step [400/938], Loss: 0.0004
# Epoch [14/20], Step [500/938], Loss: 0.0008
# Epoch [14/20], Step [600/938], Loss: 0.0074
# Epoch [14/20], Step [700/938], Loss: 0.0063
# Epoch [14/20], Step [800/938], Loss: 0.0001
# Epoch [14/20], Step [900/938], Loss: 0.0052
# Train Accuracy: 1.0000
# Test Accuracy: 0.9804
# Epoch [15/20], Step [100/938], Loss: 0.0027
# Epoch [15/20], Step [200/938], Loss: 0.0015
# Epoch [15/20], Step [300/938], Loss: 0.0138
# Epoch [15/20], Step [400/938], Loss: 0.0006
# Epoch [15/20], Step [500/938], Loss: 0.0035
# Epoch [15/20], Step [600/938], Loss: 0.0025
# Epoch [15/20], Step [700/938], Loss: 0.0026
# Epoch [15/20], Step [800/938], Loss: 0.0013
# Epoch [15/20], Step [900/938], Loss: 0.0308
# Train Accuracy: 1.0000
# Test Accuracy: 0.9767
# Epoch [16/20], Step [100/938], Loss: 0.0127
# Epoch [16/20], Step [200/938], Loss: 0.0002
# Epoch [16/20], Step [300/938], Loss: 0.0015
# Epoch [16/20], Step [400/938], Loss: 0.0156
# Epoch [16/20], Step [500/938], Loss: 0.0005
# Epoch [16/20], Step [600/938], Loss: 0.0042
# Epoch [16/20], Step [700/938], Loss: 0.0139
# Epoch [16/20], Step [800/938], Loss: 0.0000
# Epoch [16/20], Step [900/938], Loss: 0.0007
# Train Accuracy: 1.0000
# Test Accuracy: 0.9797
# Epoch [17/20], Step [100/938], Loss: 0.0000
# Epoch [17/20], Step [200/938], Loss: 0.0003
# Epoch [17/20], Step [300/938], Loss: 0.0001
# Epoch [17/20], Step [400/938], Loss: 0.0014
# Epoch [17/20], Step [500/938], Loss: 0.0007
# Epoch [17/20], Step [600/938], Loss: 0.0001
# Epoch [17/20], Step [700/938], Loss: 0.0011
# Epoch [17/20], Step [800/938], Loss: 0.0000
# Epoch [17/20], Step [900/938], Loss: 0.0030
# Train Accuracy: 1.0000
# Test Accuracy: 0.9812
# Epoch [18/20], Step [100/938], Loss: 0.0012
# Epoch [18/20], Step [200/938], Loss: 0.0014
# Epoch [18/20], Step [300/938], Loss: 0.0004
# Epoch [18/20], Step [400/938], Loss: 0.0002
# Epoch [18/20], Step [500/938], Loss: 0.0054
# Epoch [18/20], Step [600/938], Loss: 0.0268
# Epoch [18/20], Step [700/938], Loss: 0.0043
# Epoch [18/20], Step [800/938], Loss: 0.0551
# Epoch [18/20], Step [900/938], Loss: 0.0549
# Train Accuracy: 1.0000
# Test Accuracy: 0.9804
# Epoch [19/20], Step [100/938], Loss: 0.0001
# Epoch [19/20], Step [200/938], Loss: 0.0002
# Epoch [19/20], Step [300/938], Loss: 0.0000
# Epoch [19/20], Step [400/938], Loss: 0.0010
# Epoch [19/20], Step [500/938], Loss: 0.0074
# Epoch [19/20], Step [600/938], Loss: 0.0007
# Epoch [19/20], Step [700/938], Loss: 0.0021
# Epoch [19/20], Step [800/938], Loss: 0.0000
# Epoch [19/20], Step [900/938], Loss: 0.0005
# Train Accuracy: 1.0000
# Test Accuracy: 0.9783
# Epoch [20/20], Step [100/938], Loss: 0.0000
# Epoch [20/20], Step [200/938], Loss: 0.0002
# Epoch [20/20], Step [300/938], Loss: 0.0006
# Epoch [20/20], Step [400/938], Loss: 0.0000
# Epoch [20/20], Step [500/938], Loss: 0.0024
# Epoch [20/20], Step [600/938], Loss: 0.0000
# Epoch [20/20], Step [700/938], Loss: 0.0012
# Epoch [20/20], Step [800/938], Loss: 0.0003
# Epoch [20/20], Step [900/938], Loss: 0.0239
# Train Accuracy: 1.0000
# Test Accuracy: 0.9818
# 模型的training_time为429.05秒
